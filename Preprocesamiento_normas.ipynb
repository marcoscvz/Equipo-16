# %%
# !pip install PyPDF2

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        for page_num in range(num_pages):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

# %%
pdf_path = "/content/NMX-CC-19011-IMNC-2012 DIRECTRICES PARA LA AUDITORIA DE LOS SISTEMAS DE GESTION.pdf"
text = extract_text_from_pdf(pdf_path)
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# La segunda edición de esta Norma Mexicana cancela y
# reemplaza a la primera edición NMX -CC-SAA -19011 -IMNC -2002 . NORMA MEXICANA IMNC
# Directrices para la auditoría de  los sistemas de
# gestión  ISO 19011:2011
# NMX -CC-19011 -IMNC -2012
#
# Guidelines for auditing management systems
# PROHIBIDA SU REPRODUCCIÓN  PARCIAL O TOTAL – DERECHOS RESERVADOS © IMNC 2012
# NMX -CC-19011 -IMNC -2012    ISO 19011: 2011
# Derechos Reservados © IMNC 2012
# Reservados los derechos de reproducción. Salvo prescripción diferente, no podrá reproducirse ni utilizarse
# ninguna parte de esta publicación bajo ninguna forma y por ningún procedimiento, electrónico o mecánico,
# fotocopias y microfilms.
# Derechos reservados © IMNC ®
# Manuel María Contreras 133, 6º piso, Col. Cuauhtém oc
# Estados Unidos Mexicanos, México, Distrito Federal, código postal 06500
# Estados Unidos Mexicanos
# Teléfono:  + 52 55 55 66 47 50
# Fax:  + 52 55 57 05 36 86
# ...

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
dfx = text

# %%
dfx
# Out:
# ' \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nLa segunda edición de esta Norma Mexicana cancela y \nreemplaza a la primera edición NMX -CC-SAA -19011 -IMNC -2002 . NORMA MEXICANA IMNC  \nDirectrices para la auditoría de  los sistemas de \ngestión  ISO 19011:2011  \nNMX -CC-19011 -IMNC -2012  \n \nGuidelines for auditing management systems      \nPROHIBIDA SU REPRODUCCIÓN  PARCIAL O TOTAL – DERECHOS RESERVADOS © IMNC 2012  \nNMX -CC-19011 -IMNC -2012    ISO 19011: 2011  \nDerechos Reservados © IMNC 2012  \nReservados los derechos de reproducción. Salvo prescripción diferente, no podrá reproducirse ni utilizarse \nninguna parte de esta publicación bajo ninguna forma y por ningún procedimiento, electrónico o mecánico, \nfotocopias y microfilms.  \nDerechos reservados © IMNC ®  \nManuel María Contreras 133, 6º piso, Col. Cuauhtém oc \nEstados Unidos Mexicanos, México, Distrito Federal, código postal 06500  \nEstados Unidos Mexicanos  \nTeléfono:  + 52 
# ...

# %%
sw = stopwords.words('spanish')
print(len(sw))
print(sw)
# Out:
# 313
# ...

# %%
def clean_tok(tokens):

    tokens = tokens.lower() # convierte todo el texto en minusculas
    tokens = tokens.translate(str.maketrans('.',' ')) # solucion a palabras unidas por .
    tokens = tokens.translate(str.maketrans('','',string.punctuation)) # depura signos de puntuacion y caracteres especiales
    tokens = nltk.word_tokenize(tokens) #genera los tokens
    tokens = [token for token in tokens if token not in sw] #Elimina las stopword de la lista
    tokens = [token for token in tokens if len(token) > 1] # Elimina tokens menores a 1 caracter

    return(tokens)

# %%
#cleandf = [clean_tok(x) for x in dfx]
cleandf = clean_tok(dfx)

# %%
cleandf
# Out:
# ['segunda',
#  'edición',
#  'norma',
#  'mexicana',
#  'cancela',
#  'reemplaza',
#  'primera',
#  'edición',
#  'nmx',
#  'ccsaa',
#  '19011',
#  'imnc',
#  '2002',
#  'norma',
#  'mexicana',
#  'imnc',
#  'directrices',
#  'auditoría',
#  'sistemas',
#  'gestión',
#  'iso',
#  '190112011',
#  'nmx',
#  'cc19011',
#  'imnc',
#  '2012',
#  'guidelines',
#  'for',
#  'auditing',
#  'management',
#  'systems',
#  'prohibida',
#  'reproducción',
#  'parcial',
#  'total',
#  'derechos',
#  'reservados',
#  'imnc',
#  '2012',
#  'nmx',
#  'cc19011',
#  'imnc',
#  '2012',
#  'iso',
#  '19011',
#  '2011',
#  'derechos',
#  'reservados',
#  'imnc',
#  '2012',
#  'reservados',
#  'derechos',
#  'reproducción',
#  'salvo',
#  'prescripción',
#  'diferente',
#  'podrá',
#  'reproducirse',
#  'utilizarse',
#  'ninguna',
#  'parte',
#  'publicación',
#  'bajo',
#  'ninguna',
#  'forma',
#  'ningún',
#  'procedimiento',
#  'electrónico',
#  'mecánico',
#  'fotocopias',
#  'microfilms',
# ...

# %%
wordlem = WordNetLemmatizer()

def clean_doc(doc):

    doc = [wordlem.lemmatize(i, 'v') for i in doc] # lematizacion verbos
    doc = [wordlem.lemmatize(i, 'n') for i in doc] # lematizacion pronombres
    doc = [wordlem.lemmatize(i, 'r') for i in doc] # lematizacion adverbios
    doc = [w for w in doc if w.isalpha()] #no se tienen en cuenta #
    doc = list(set(doc)) # elimiacion duplicados
    doc = [token for token in doc if len(token) > 1] #se vuelve a depuran token menores a 1

    return doc

# %%
Xclean = clean_doc(cleandf)

# %%
len(Xclean)
# Out:
# 2397

# %%
Xclean
# Out:
# ['seguimiento',
#  'ubicación',
#  'real',
#  'común',
#  'conversión',
#  'cerradas',
#  'measurement',
#  'alcanzarán',
#  'sujetos',
#  'finalice',
#  'pretendi',
#  'prefiere',
#  'amplió',
#  'nde',
#  'partir',
#  'finalizada',
#  'suceso',
#  'personalmente',
#  'identificaci',
#  'civil',
#  'gusto',
#  'centro',
#  'cliente',
#  'acerca',
#  'cia',
#  'federación',
#  'realice',
#  'unión',
#  'autodeclaración',
#  'eficaces',
#  'residuos',
#  'fó',
#  'mencionados',
#  'exicana',
#  'contratantes',
#  'necesitan',
#  'bolivia',
#  'tomarse',
#  'evaluarlos',
#  'fuentes',
#  'desarrollarse',
#  'población',
#  'muestrear',
#  'alcanzado',
#  'tecnología',
#  'reactivas',
#  'excepto',
#  'interpretación',
#  'inara',
#  'subyacentes',
#  'interrumpirse',
#  'siendo',
#  'requisito',
#  'obtención',
#  'procedim',
#  'ayudan',
#  'patrón',
#  'prevenir',
#  'acuerdos',
#  'especiales',
#  'clave',
#  'ralidades',
#  'seguir',
#  'antecedentes',
#  'evalúa',
#  'ía',
# ...
